# %% [markdown]
# ## Cloning Github Repository and navigating folders

# %%
# !git clone https://github.com/JacopoCalvano/Copia_di_Copia_di_Untitled14
# !ls Copia_di_Copia_di_Untitled14
# %cd /kaggle/working/Copia_di_Copia_di_Untitled14
# Out:
# Cloning into 'Copia_di_Copia_di_Untitled14'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 75 (delta 32), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 305.01 KiB | 7.63 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# 'Feature Importance'   LICENSE	 main.ipynb   main.py   README.md
# /kaggle/working/Copia_di_Copia_di_Untitled14

# %% [markdown]
# ## Start the models
#
# For a better viewing experience and to follow our reasoning, see the notebook in the github repository: [LINK](https://github.com/JacopoCalvano/Copia_di_Copia_di_Untitled14/blob/main/main.ipynb)
#
#
# Given the dataset path our code will train the models, print some statistics and create 3 csv of predictions on the dataset provided.

# %%
#Dataset path, modify with your own
dataset_path = '/kaggle/input/fds-pokemon-battles-prediction-2025/test.jsonl' #default
#dataset_path = '' #modify here

# %%
# !python main.py --dataset {dataset_path} --output /kaggle/working/
# Out:
# Loading dataset...
# Applying feature engineering...
# Training models...
# KNN trained
# XGBoost trained
# SVM trained
# SUMMARIES OF THE MONO-MODELS
#          Train Acc  Val Acc  Overfitting Gap  ...  Val Rec  Train Loss  Val Loss
# Model                                         ...
# KNN         0.8396   0.8511           0.0115  ...   0.8503      0.3745    0.4795
# XGBoost     0.8582   0.8622           0.0040  ...   0.8590      0.3292    0.3546
# SVM         0.8344   0.8633           0.0290  ...   0.8698      0.3850    0.3561
#
# [3 rows x 9 columns]
# Reliability Weights:
# KNN: 23.4%
# XGB: 67.3%
# SVM: 9.3%
# SUMMARIES OF MONO-MODELS + METAMODEL
#                  Train Acc  Val Acc  ...  Train Loss  Val Loss
# Model                                ...
# KNN                 0.8396   0.8511  ...      0.3745    0.4795
# XGBoost             0.8582   0.8622  ...      0.3292    0.3546
# SVM                 0.8344   0.8633  ...      0.3850    0.3561
# ...
